# %% [markdown]
# <img src = "https://www.bits-pilani.ac.in/Uploads/Campus/BITS_university_logo.gif">

# %% [markdown]
# <h1><center>Work Integrated Learning Programmes Division<br>
# M.Tech (Data Science and Engineering)<br> Data Visualization And Interpretation (DSECL ZG555))<br>
# Second Semester, 2021-22
# </center></h1>
#
# <h2><center>Assignment 2 – PS7 [Weightage 13%]</center></h2>

# %% [markdown]
# ## Instructions
# <ol>
#   <li>Do not change the name of the data file that is shared with the problem statement.</li>
#   <li>If intermediate data files are created, retain in the present working directory and attach them during submission.</li>
#   <li>Retain the data file in the same directory as that of this workbook.</li>
#   <li>Retain the Visualizations that is produced in the file. Don't clear them away.</li>
#     <li><div class="alert-warning">All the visuals should adhere to the visualization principles learnt in the Course and must be presentation ready. Most effective visuals would fetch maximum credits</div></li>
#     <li><div class="alert-warning">Submissions done via means other than CANVAS will strictly be NOT graded.</div></li>
#
#
#
#
# </ol>

# %% [markdown]
# <style>
# table {
#   font-family: arial, sans-serif;
#   border-collapse: collapse;
#   width: 100%;
# }
#
# td, th {
#   border: 1px solid #dddddd;
#   text-align: left;
#   padding: 8px;
# }
#
# tr:nth-child(even) {
#   background-color: #dddddd;
# }
# </style>
#
# <h2>Group No: 94</h2>
#
# <table>
#   <tr>
#     <th>Full Name</th>
#     <th>BITS ID</th>
#   </tr>
#   <tr>
#     <td>Kovvuri Satyanarayana Reddy</td>
#     <td>2022dc04282</td>
#   </tr>
#   <tr>
#     <td>Narem Chiradeep Reddy</td>
#     <td>2022dc04014</td>
#   </tr>
#   <tr>
#     <td>Kovvuri Narendra Reddy</td>
#     <td>2022dc04283</td>
#   </tr>
# </table>

# %% [markdown]
# <h1>Objective</h1>
# <h4>Perform EDA on the data set.</h4>

# %% [markdown]
# ##  Download and Prep the Data: 1 Mark

# %% [markdown]
# <h4>Import the libraries needed</h4>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# C:\Users\ksnr9\AppData\Local\Temp\ipykernel_11160\845136906.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# <h4> Load data and store in dataframe </h4>

# %%
df = pd.read_csv("dvi-a2-ps7-data.csv")
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity     Total        Date   Time  \
# 0       Health and beauty       74.69         7  548.9715  01-05-2019  13:08
# 1  Electronic accessories       15.28         5   80.2200  03-08-2019  10:29
#
#    Payment  costofgoodssold  Rating
# 0  Ewallet           522.83     9.1
# 1     Cash            76.40     9.6

# %% [markdown]
# <h4>Find out  what type of variable you are dealing with. This will help you find the right visualization method for that variable.</p>

# %%
df.dtypes
# Out:
# Invoice ID          object
# Branch              object
# City                object
# Customer type       object
# Gender              object
# Product line        object
# Unit price         float64
# Quantity             int64
# Total              float64
# Date                object
# Time                object
# Payment             object
# costofgoodssold    float64
# Rating             float64
# dtype: object

# %% [markdown]
# #### Display the summary statistics of the data.In a markdown cell below,explain your findings

# %%
df.describe(include='all')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
# mean            NaN    NaN     NaN           NaN     NaN                  NaN
# std             NaN    NaN     NaN           NaN     NaN                  NaN
# min             NaN    NaN     NaN           NaN     NaN                  NaN
# 25%             NaN    NaN     NaN           NaN     NaN                  NaN
# 50%             NaN    NaN     NaN           NaN     NaN                  NaN
# 75%             NaN    NaN     NaN           NaN     NaN                  NaN
# max             NaN    NaN     NaN           NaN     NaN                  NaN
#
# ...

# %% [markdown]
# The table provides a summary of descriptive statistics for various columns in a dataset:
#
# - **Invoice ID**: There are 1000 unique invoice IDs, each appearing only once.
# - **Branch**: There are 1000 entries, distributed across three branches. Branch A has the highest frequency, occurring 340 times.
# - **City**: There are three unique cities.
# - **Customer type**: There are three types of customers, with "Member" being the most frequent.
# - **Gender**: There are two genders, with "Female" being the most frequent.
# - **Product line**: There are six unique product lines, with "Fashion accessories" being the most frequent.
# - **Unit price**: The mean unit price is approximately $55.67, with a standard deviation of approximately $26.49.
# - **Quantity**: The mean quantity purchased is approximately 5.51, with a standard deviation of approximately 2.92.
# - **Total**: The mean total purchase amount is approximately $322.97, with a standard deviation of approximately $245.89.
# - **Payment**: There are three payment methods, with "Ewallet" being the most frequent.
# - **Cost of goods sold**: The mean cost of goods sold is approximately $307.59, with a standard deviation of approximately $234.18.
# - **Rating**: The ratings range from 4 to 10, with a mean rating of approximately 6.97.oximately 6.97.

# %% [markdown]
# #### Identify whether male/female spends more on 'Health and beauty'.Write the code below

# %%
spending_data = df[df['Product line']=='Health and beauty'].groupby('Gender')['Total'].sum()

print("Male Spending: ", spending_data['Male'])
print("Female Spending: ", spending_data['Female'])

if spending_data['Male'] > spending_data['Female']:
    print("\nMale spends more than Female on Health and beauty")
elif spending_data['Male'] < spending_data['Female']:
    print("\nFemale spends more than Male on Health and beauty")
else:
    print("\nMale and Female spends equally on Health and beauty")
# Out:
# Male Spending:  30632.7525
# Female Spending:  18560.9865
#
# Male spends more than Female on Health and beauty

# %% [markdown]
# # Visualisation Questions - 2 X 5 = 10 Marks

# %% [markdown]
# ### Question 1
# <h4>Check the distribution of the Price variable .<br><br>
#     Write the python code in the below cell to create appropriate visual to perform the above task.
# <h4>Answer in markdown cells below the visual <br><br>
#     1.Summarise your findings from the visual.<br>
#     2.The reason for selecting the chart type you did. <br>
#     3.Mention the pre-attentive attributes used.(atleast 2)<br>
#     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
sns.displot(data=df, x='Unit price', bins=20, height=6, aspect=2, edgecolor='black')
plt.title("Distribution of Unit Price", fontweight='bold')
plt.xticks(range(10, 110, 10))
plt.show()

# %% [markdown]
# **Findings**: The histogram illustrates the distribution of unit prices within the dataset. The majority of unit prices fall within the range of approximately 10 to 100, with the highest frequency observed around 50 to 60. The distribution appears to be somewhat Uniformly distributed.
#
# **Reason for Chart Type Selection**: A distplot is chosen for this visualization because it effectively represents the frequency distribution of continuous data, such as unit prices. It allows viewers to grasp the distribution pattern and understand the concentration of values within specific ranges.
#
# **Pre-attentive Attributes**:
# - Length: The length of each bar represents the frequency or count of unit prices falling within the corresponding range, aiding in easy comparison.
# - Color: The use of color (blue) distinguishes the bars from the background and enhances visual appeal, making it easier for viewers to focus on the data.
#
# **Gestalt Principles**:
# - Proximity: The bars are grouped closely together, indicating the proximity of data points within specific price ranges. This proximity helps viewers perceive clusters and patterns in the distribution.
# - Continuity: The bars form a continuous distribution, allowing viewers to perceive the overall trend and flow of unit prices across the dataset without interruption. This continuity aids in understanding the shape and characteristics of the distribution.istribution.

# %% [markdown]
# ### Question 2
# <h4>What does the distribution of customer rating looks like? Draw the mean,25th and 75th percentile on the plot.<br><br>
#     Write the python code in the below cell to create the appropriate visual to perform the above task .
# <h4>Answer in markdown cells below the visual <br><br>
#     1.Summarise your findings from the visual.<br>
#     2.The reason for selecting the chart type you did. <br>
#     3.Mention the pre-attentive attributes used.(atleast 2)<br>
#     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
fig, ax = plt.subplots(figsize=(12, 4))
sns.boxplot(data=df, x='Rating', ax=ax, width=0.5)

# Calculate mean, 25th, and 75th percentiles
mean_rating = df['Rating'].mean()
percentile_25 = df['Rating'].quantile(0.25)
percentile_75 = df['Rating'].quantile(0.75)

# Plot mean, 25th, and 75th percentiles as vertical lines
plt.axvline(mean_rating, color='red', linestyle='--', label='Mean')
plt.axvline(percentile_25, color='green', linestyle='--', label='25th Percentile')
plt.axvline(percentile_75, color='orange', linestyle='--', label='75th Percentile')
plt.legend()
plt.title("Distribution of Customer Rating with mean, 25 and 75 Quartile.")

plt.show()

# %% [markdown]
# 1. **Findings from the Visual:**
#    - The boxplot illustrates the distribution of customer ratings, with key summary statistics marked by horizontal lines within the box.
#    - The median rating (50th percentile) appears to be around 7, as indicated by the red dashed line.
#    - The interquartile range (IQR), represented by the width of the box, suggests that the majority of ratings fall between approximately 5.5 and 8.5
#    - Outliers are not present in this box plot.
#
# 2. **Reason for Selecting Boxplot:**
#    - We choose a boxplot because it effectively summarizes the distribution of numerical data and highlights key summary statistics such as the median, quartiles, and outliers.
#    - It allows for easy comparison of the rating distribution and provides insights into the spread and central tendency of the data.
#
# 3. **Pre-attentive Attributes Used:**
#    - Length: The length of the box and whiskers provides a quick understanding of the spread of the ratings, with longer whiskers indicating a larger range of ratings.
#    - Color: Different colors are used for the mean and quartile lines, making them stand out from the rest of the plot and drawing attention to these key summary statistics.
#
# 4. **Gestalt Principles Used:**
#    - Proximity: The proximity of the quartile lines and the mean line to the boxplot elements suggests their association with the distribution of ratings, aiding in the interpretation of summary statistics.
#    - Closure: The closed box in the boxplot visually encapsulates the interquartile range, making it easy to identify and compare the central spread of ratings.

# %% [markdown]
# ### Question 3
# <h4>For each payment method,compare the product lines. Does any stand out?<br><br>
#     Write the python code in the below cell to create appropriate visual to perform the above task.
# <h4>Answer in markdown cells below the visual <br><br>
#     1.Summarise your findings from the visual.<br>
#     2.The reason for selecting the chart type you did. <br>
#     3.Mention the pre-attentive attributes used.(atleast 2)<br>
#     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
plt.figure(figsize=(14, 12))
#sns.palplot(sns.color_palette("BuGn_r", 10)) 
sns.countplot(data=df, x='Payment', hue='Product line', palette='flare')

# Add labels and title
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.title('Comparison of Product Lines by Payment Method')

# Rotate x-axis labels for better readability
plt.xticks()

# Show plot
plt.legend(title='Product Line')
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. **Findings from the Visual:**
#    - The bar graph compares the count of transactions for different product lines across various payment methods
#    - In *"EWallet"* Method *"Home and Lifestyle"* and *"Fashion accessories"* are the most prefered products.
#    - *"Electronic accessories"* in the *"Cash Payment Method"* is having highest count.
#    - In *"Credit Card"* Transactions *"Food and Beverages"* is the Highest prefered.d."
#    - The count of transactions varies across product lines within each payment method, indicating different popularity levels amotg it
# ms.
#
# 2. **Reason for Selecting the Chart Type:**
#    - A grouped bar chart is suitable for comparing multiple categories (product lines) across difent subcategories (payment methods).
#    - It allows for a straightforward comparison of the count of transactions for each product line within each payment method.
#
# 3. **Pre-attentive Attributes Used:**
#    - Length/Height: The height of each bar represents the count of transactions, allowing for easy quantitative comparison between product lines and payment methods.
#    - Position: The position of bars relative to each other within the same payment method facilitates comparison between different product lines.
#
# 4. **Gestalt Principles Used:**
#    - Similarity: Bars of the same color represent transactions within the same product line, making it easy to identify and compare them.
#    - Proximity: Bars grouped together represent transactions within the same payment method, emphasizing their relationship.

# %% [markdown]
# ### Question 4
# <h4>Identify, which is the most appropriate time(hour) to give online disount?<br><br>
#     Write the python code in the below cell to create the appropriate visual(single visual) to perform the above task .(Prep the data as necessary)
# <h4>Answer in markdown cells below the visual <br><br>
#     1.Summarise your findings from the visual.<br>
#     2.The reason for selecting the chart type you did. <br>
#     3.Mention the pre-attentive attributes used.(atleast 2)<br>
#     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity     Total        Date   Time  \
# 0       Health and beauty       74.69         7  548.9715  01-05-2019  13:08
# 1  Electronic accessories       15.28         5   80.2200  03-08-2019  10:29
#
#    Payment  costofgoodssold  Rating
# 0  Ewallet           522.83     9.1
# 1     Cash            76.40     9.6

# %%
df['Hour'] = pd.to_datetime(df['Time']).dt.hour
fig, ax1 = plt.subplots(figsize=(10, 6))
sns.histplot(df['Hour'], bins=10, ax=ax1, color="gray")
ax1.patches[9].set_facecolor('green') 
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Purchases')
plt.title('Distribution of Purchases Over Hours of the Day')
plt.xticks(range(9, 21))
# Show plot
plt.show()
# Out:
# C:\Users\ksnr9\AppData\Local\Temp\ipykernel_11160\2432008472.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Hour'] = pd.to_datetime(df['Time']).dt.hour

# %% [markdown]
# **Findings:**
# - The distribution of purchases over hours of the day shows that the highest number of purchases occurs around the evening hours, particularly between 19:00 and 20:00.
# - There is a noticeable decrease in purchases from 16:00 to 18:00, indicating a decline in shopping activity during evening hours.
#
# **Chart Type:**
# We choose a histogram to visualize the distribution of purchases over hours of the day because it effectively displays the frequency distribution of a continuous variable (hours) in this case. A histogram allows us to easily identify peaks and patterns in the data, making it suitable for analyzing the distribution of purchases over different hours.
#
# **Pre-attentive Attributes:**
# 1. Color: The use of different colors, particularly highlighting the highest hour with green, helps draw attention to specific points in the distribution.
# 2. Length: The length of the bars in the histogram represents the frequency of purchases, allowing for quick comparison between different hours.
#
# **Gestalt Principles:**
# 1. Proximity: The bars are grouped together based on their proximity on the x-axis, making it easy to perceive different clusters of hours and their corresponding purchase frequencies.
# 2. Focal Point: Green bar focuses and represents the hour with highest no.of purchases in 19:00 to 20:00 hour.
# 3. Continuity: The continuous flow of bars from one hour to the next creates a sense of continuity, allowing viewers to interpret the progression of purchases throughout the day.

# %% [markdown]
# ### Question 5

# %% [markdown]
# <h4>Which product line is more profitable?<br><br>
#     Write the python code in the below cell to create the appropriate visual(single visual) to perform the above task .(Prep the data as necessary)
# <h4>Answer in markdown cells below the visual <br><br>
#     1.Summarise your findings from the visual.<br>
#     2.The reason for selecting the chart type you did. <br>
#     3.Mention the pre-attentive attributes used.(atleast 2)<br>
#     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
df['Profit'] = df['Total'] - df['costofgoodssold']
fig, ax1 = plt.subplots(figsize=(10, 6))
new = df.groupby(['Product line'])['Profit'].sum().sort_values(ascending=False)
sns.barplot(x=new.values, y=new.index, width=0.6, ax=ax1)

plt.title('Profit by Product Line', pad=15)
plt.xlabel('Total Profit')
plt.ylabel('Product Line')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Findings from the Visual:**
# - The product line "Food and Beverages" appears to be the most profitable, followed by "Sports and travel" and "Electronic accessories".
# - "Health and beauty" is the least profitable product lines.
# - There is a significant disparity in profitability among the different product lines, indicating varying levels of success in sales and cost management.
#
# **Reason for Selecting the Chart Type:**
# we have selected a horizontal bar chart because it effectively compares the profitability of different product lines. Horizontal bars allow for easy comparison of the lengths, making it straightforward to identify which product lines are more profitable. Additionally, the use of bars allows for clear visualization of the magnitude of profitability differences between the product lines.
#
# **Pre-attentive Attributes Used:**
# 1. Length: The length of each bar represents the total profit generated by each product line, making it easy to compare the profitability visually.
# 2. Color: Although not explicitly mentioned, the bars might have different colors to distinguish between different product lines, aiding in easy identification.
#
# **Gestalt Principles Used:**
# 1. Proximity: Bars belonging to the same product line are positioned closer to each other, emphasizing their relationship and making it easier for viewers to group and compare them.
# 2. Continuity: The continuous arrangement of bars along the y-axis helps viewers perceive the overall trend in profitability across different product lines without interruption, facilitating a smooth visual flow.

# %% [markdown]
# # Group's choice-2 Marks
#
# #### Frame 1 (more) question which will help in the EDA(Exploratory Data Analysis) of the given data set and answer the same using the best visual.
#
#  1. Write the question in a markdown cell
#  2. Below the question, in a coding cell, write the python code to create the visual to answer the question
#
# <h4> Answer in markdown cells below the visual <br><br>
#    1.Summarise your findings from the visual.<br>
#    2.The reason for selecting the chart type you did. <br>
#    3.Mention the pre-attentive attributes used.(atleast 2)<br>
#    4.Mention the gestalt principles used.(atleast 2)<br>

# %% [markdown]
# ## Comparision of Product lines based on Gender.

# %%
# Create a stacked bar plot
plt.figure(figsize=(14, 12))
#sns.palplot(sns.color_palette("BuGn_r", 10)) 
sns.countplot(data=df, x='Gender', hue='Product line', palette='viridis')

# Add labels and title
plt.xlabel('Gender Category')
plt.ylabel('Count')
plt.title('Comparison of Product Lines based on Gender')

# Rotate x-axis labels for better readability
plt.xticks()

# Show plot
plt.legend(title='Product Line')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Findings from the visual:**
# - The visual presents a comparison of product lines based on gender categories (Male, Female). Each bar represents the count of different product lines for each gender category.
# - In the *Female* category *Fashon accessories*, *Food and Beverages* are the highest prefered product lines.
# - In the *Male* category *Health and beauty* and *Electronic accessories* are the highest prefered product lines.
#
# **Reason for selecting the chart type:**
# - A grouped bar chart is chosen because it allows for the comparison of multiple categories (product lines) within each gender category.
# - Grouped bars visually represent the composition of each category (gender) in terms of subcategories (product lines), making it easy to compare the distribution of product lines across genders.
#
# **Pre-attentive attributes used:**
# - **Color:** Different colors are used to represent different product lines within each gender category. This helps in distinguishing between the product lines quickly.
# - **Length/Height:** The length of each stacked bar represents the count of product lines, making it easy to compare the counts visually.
#
# **Gestalt principles used:**
# - **Proximity:** Within each gender category, the product lines are grouped closely together, emphasizing their relationship and making it easier for viewers to associate each product line with its respective gender category.
# - **Similarity:** Product lines belonging to the same gender category are visually similar in terms of color (belonging to the same palette) and shape (grouped bars), aiding in the perception of groups and facilitating comparison within each gender category.

# %% [markdown]
# <h1><center> ************ END OF ASSIGNMENT ****************</center></h1>
